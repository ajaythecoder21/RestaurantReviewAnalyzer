# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("RestaurantReviews.csv")

# %%
df.head()
# Out:
#    Unnamed: 0            Restaurant Name  \
# 0           0    ZuZu at Hotel Valley Ho
# 1           1            1. Cafe Monarch
# 2           2          2. Mowry & Cotton
# 3           3  3. Franco's Italian Caffe
# 4           4      4. The Capital Grille
#
#                                          Review Text    Type of Restaurant
# 0                           “Fab Breakfast and Bar!”         American, Bar
# 1  “... beef tartare, a seafood tower, beet salad...              American
# 2  “The food was great (try the meatballs) and th...              American
# 3  “A simple green salad, a glass of red wine and...       Italian, Tuscan
# 4  “... accompany our great flourless chocolate c...  American, Steakhouse

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %%
df.head()
# Out:
#              Restaurant Name  \
# 0    ZuZu at Hotel Valley Ho
# 1            1. Cafe Monarch
# 2          2. Mowry & Cotton
# 3  3. Franco's Italian Caffe
# 4      4. The Capital Grille
#
#                                          Review Text    Type of Restaurant
# 0                           “Fab Breakfast and Bar!”         American, Bar
# 1  “... beef tartare, a seafood tower, beet salad...              American
# 2  “The food was great (try the meatballs) and th...              American
# 3  “A simple green salad, a glass of red wine and...       Italian, Tuscan
# 4  “... accompany our great flourless chocolate c...  American, Steakhouse

# %%
# Data Preprocessing
#df['Restaurant Name'] = df['Restaurant Name'].replace(str(df.index) + '.', '')

# %%
df.head()
# Out:
#              Restaurant Name  \
# 0    ZuZu at Hotel Valley Ho
# 1            1. Cafe Monarch
# 2          2. Mowry & Cotton
# 3  3. Franco's Italian Caffe
# 4      4. The Capital Grille
#
#                                          Review Text    Type of Restaurant
# 0                           “Fab Breakfast and Bar!”         American, Bar
# 1  “... beef tartare, a seafood tower, beet salad...              American
# 2  “The food was great (try the meatballs) and th...              American
# 3  “A simple green salad, a glass of red wine and...       Italian, Tuscan
# 4  “... accompany our great flourless chocolate c...  American, Steakhouse

# %%
import nltk

#for i in df['Restaurant Name']:
   #a = nltk.word_tokenize(i)   
   #print(a)
   #if str(a[0]).isnumeric():
      # a = a[1:]
       #i = ''.join(a)
#df['Restaurant Name']

# %%
#some_name = str(df.index) + '.'
#if df['Restaurant Name'].str.contains('123.'):
df['Restaurant Name'] = df['Restaurant Name'].str.strip('123456789101112131415161718192021222324252627282930.')
    #print(i.loc['Restaurant Name'])
    #print('Hi')
df['Restaurant Name']
# Out:
# 0                       ZuZu at Hotel Valley Ho
# 1                                  Cafe Monarch
# 2                                Mowry & Cotton
# 3                        Franco's Italian Caffe
# 4                            The Capital Grille
# 5                   Butterfield's Pancake House
# 6                              JOJO Coffeehouse
# 7                                        Craft
# 8                                         Virtu
# 9                          Rehab Burger Therapy
# 10                      Butters Pancakes & Cafe
# 11                   Grassroots Kitchen and Tap
# 12                                       Steak
# 13     Elements at Sanctuary Camelback Mountain
# 14                       Roka Akor - Scottsdale
# 15                                        deseo
# 16                      Eddie V's Prime Seafood
# 17                        Dominick's Steakhouse
# 18                            True Food Kitchen
# 19                          Snooze an AM Eatery
# ...

# %%
df.head()
# Out:
#            Restaurant Name                                        Review Text  \
# 0  ZuZu at Hotel Valley Ho                           “Fab Breakfast and Bar!”
# 1             Cafe Monarch  “... beef tartare, a seafood tower, beet salad...
# 2           Mowry & Cotton  “The food was great (try the meatballs) and th...
# 3   Franco's Italian Caffe  “A simple green salad, a glass of red wine and...
# 4       The Capital Grille  “... accompany our great flourless chocolate c...
#
#      Type of Restaurant
# 0         American, Bar
# 1              American
# 2              American
# 3       Italian, Tuscan
# 4  American, Steakhouse

# %%
#import spacy
from nltk.corpus import stopwords
stopWords = set(stopwords.words('english'))
stopWords
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
df['BagofWords'] = df['Review Text'].apply(lambda x: x.lower())

# %%
text_2 = ''.join(df['BagofWords'])
text_2
# Out:
# "“fab breakfast and bar!”“... beef tartare, a seafood tower, beet salad, duck breast and a salmon dish.”“the food was great (try the meatballs) and the atmosphere was fantastic!”“a simple green salad, a glass of red wine and franco's scrumptious lasagna.”“... accompany our great flourless chocolate cake and the best cheesecake ever.”“known for their pancakes, but recommend the breakfast burrito!”“the coffee flight was amazing!”“many different beers they brew, plus a wall of other craft beers give plenty...”“we had an excellent a salad followed by a absolutely delicious sea bass entrée.”“... it was a southwestern type of salad with really fresh greens, spicy chick...”“breakfast brunch”“still the best burger and fries i know.”“definitely get the beignets that are brought to you in a display of each beig...”“... to start, and then for entrees we had the pork chop and the sea bass.”“if you go and try the omakase, be prepared for a lot of amazing food 😁”“... to try the pisco sour which to
# ...

# %%
for i in stopWords:
    if i in text_2:
        text_2 = text_2.strip(i)
text_2
# Out:
# "“fab breakfast and bar!”“... beef tartare, a seafood tower, beet salad, duck breast and a salmon dish.”“the food was great (try the meatballs) and the atmosphere was fantastic!”“a simple green salad, a glass of red wine and franco's scrumptious lasagna.”“... accompany our great flourless chocolate cake and the best cheesecake ever.”“known for their pancakes, but recommend the breakfast burrito!”“the coffee flight was amazing!”“many different beers they brew, plus a wall of other craft beers give plenty...”“we had an excellent a salad followed by a absolutely delicious sea bass entrée.”“... it was a southwestern type of salad with really fresh greens, spicy chick...”“breakfast brunch”“still the best burger and fries i know.”“definitely get the beignets that are brought to you in a display of each beig...”“... to start, and then for entrees we had the pork chop and the sea bass.”“if you go and try the omakase, be prepared for a lot of amazing food 😁”“... to try the pisco sour which to
# ...

# %%
tokenized_text_2 = nltk.word_tokenize(text_2)
tokenized_text_2
punct = [",", ',', '...', '.', '(', ')', '!', '?', '-', ':', ';']
tokenized_text_2
# Out:
# ['“',
#  'fab',
#  'breakfast',
#  'and',
#  'bar',
#  '!',
#  '”',
#  '“',
#  '...',
#  'beef',
#  'tartare',
#  ',',
#  'a',
#  'seafood',
#  'tower',
#  ',',
#  'beet',
#  'salad',
#  ',',
#  'duck',
#  'breast',
#  'and',
#  'a',
#  'salmon',
#  'dish.',
#  '”',
#  '“',
#  'the',
#  'food',
#  'was',
#  'great',
#  '(',
#  'try',
#  'the',
#  'meatballs',
#  ')',
#  'and',
#  'the',
#  'atmosphere',
#  'was',
#  'fantastic',
#  '!',
#  '”',
#  '“',
#  'a',
#  'simple',
#  'green',
#  'salad',
#  ',',
#  'a',
#  'glass',
#  'of',
#  'red',
#  'wine',
#  'and',
#  'franco',
#  "'s",
#  'scrumptious',
#  'lasagna.',
#  '”',
#  '“',
#  '...',
#  'accompany',
#  'our',
#  'great',
#  'flourless',
#  'chocolate',
#  'cake',
#  'and',
#  'the',
#  'best',
#  'cheesecake',
#  'ever.',
#  '”',
#  '“',
#  'known',
#  'for',
#  'their',
#  'pancakes',
#  ',',
#  'but',
#  'recommend',
#  'the',
#  'breakfast',
#  'burrito',
#  '!',
#  '”',
#  '“',
#  'the',
#  'coffee',
#  'flight',
# ...

# %%
from string import punctuation
def clean_text(text_2):
    text_2 = "".join([j for j in text_2 if j not in punctuation])
    text_2 = text_2.lower()
    #text_2 = "".join([k for k in text_2 if k not in stopWords])
    
    return text_2

# %%
df['Cleaned_Text'] = df['Review Text'].apply(lambda c: clean_text(c))

# %%
df.head()
# Out:
#            Restaurant Name                                        Review Text  \
# 0  ZuZu at Hotel Valley Ho                           “Fab Breakfast and Bar!”
# 1             Cafe Monarch  “... beef tartare, a seafood tower, beet salad...
# 2           Mowry & Cotton  “The food was great (try the meatballs) and th...
# 3   Franco's Italian Caffe  “A simple green salad, a glass of red wine and...
# 4       The Capital Grille  “... accompany our great flourless chocolate c...
#
#      Type of Restaurant                                         BagofWords  \
# 0         American, Bar                           “fab breakfast and bar!”
# 1              American  “... beef tartare, a seafood tower, beet salad...
# 2              American  “the food was great (try the meatballs) and th...
# 3       Italian, Tuscan  “a simple green salad, a glass of red wine and...
# 4  American, Steakhouse  “... accompany our great flourless chocolate c...
#
# ...

# %%
# Out:
#            Restaurant Name                                        Review Text  \
# 0  ZuZu at Hotel Valley Ho                           “Fab Breakfast and Bar!”
# 1             Cafe Monarch  “... beef tartare, a seafood tower, beet salad...
# 2           Mowry & Cotton  “The food was great (try the meatballs) and th...
# 3   Franco's Italian Caffe  “A simple green salad, a glass of red wine and...
# 4       The Capital Grille  “... accompany our great flourless chocolate c...
#
#      Type of Restaurant                                         BagofWords  \
# 0         American, Bar                           “fab breakfast and bar!”
# 1              American  “... beef tartare, a seafood tower, beet salad...
# 2              American  “the food was great (try the meatballs) and th...
# 3       Italian, Tuscan  “a simple green salad, a glass of red wine and...
# 4  American, Steakhouse  “... accompany our great flourless chocolate c...
#
#    Cleaned_Text
# 0          True
# ...

# %%
sentiment_words = pd.read_excel('PosNegList.xlsx')

# %%
sentiment_words.head()
# Out:
#    Unnamed: 0 Negative Sense Word List Positive Sense Word List
# 0           0                      NaN                      NaN
# 1           1                 abnormal                     able
# 2           2                  abolish                abundance
# 3           3               abominable               accelerate
# 4           4               abominably                   accept

# %%
sentiment_words.drop('Unnamed: 0', axis = 1, inplace  = True)

# %%
sentiment_words.drop(0, axis = 0, inplace = True)

# %%
pos_list = [i for i in sentiment_words['Positive Sense Word List']]
pos_list
# Out:
# ['able',
#  'abundance',
#  'accelerate',
#  'accept',
#  'acclaim',
#  'accolade',
#  'accomplish',
#  'accord',
#  'accredit',
#  'accrue',
#  'ace',
#  'achieve',
#  'action',
#  'activate',
#  'active',
#  'add',
#  'addition',
#  'adept',
#  'admirable',
#  'adorable',
#  'advance',
#  'advantage',
#  'adventure',
#  'affable',
#  'affirm',
#  'ageless',
#  'agree',
#  'agreeable',
#  'aid',
#  'aim',
#  'alacrity',
#  'alert',
#  'alight',
#  'alive',
#  'all',
#  'altruistic',
#  'always',
#  'amaze',
#  'amazement',
#  'amazing',
#  'ambition',
#  'amiable',
#  'amity',
#  'amuse',
#  'anew',
#  'angel',
#  'appealing',
#  'applaud',
#  'appreciate',
#  'approve',
#  'arouse',
#  'art',
#  'as',
#  'ascend',
#  'aspire',
#  'assent',
#  'assert',
#  'assist',
#  'associate',
#  'assure',
#  'astir',
#  'astonish',
#  'attain',
#  'attempt',
#  'attention',
#  'attentive',
#  'attest',
#  'attraction',
#  'attribute',
#  'attune',
#  'augment',
#  'auspicious',
# ...

# %%
neg_list = [j for j in sentiment_words['Negative Sense Word List']]
neg_list
# Out:
# ['abnormal',
#  'abolish',
#  'abominable',
#  'abominably',
#  'abominate',
#  'abomination',
#  'abort',
#  'aborted',
#  'aborts',
#  'abrade',
#  'abrasive',
#  'abrupt',
#  'abruptly',
#  'abscond',
#  'absence',
#  'absent-minded',
#  'absentee',
#  'absurd',
#  'absurdity',
#  'absurdly',
#  'absurdness',
#  'abuse',
#  'abused',
#  'abuses',
#  'abusive',
#  'abysmal',
#  'abysmally',
#  'abyss',
#  'accidental',
#  'accost',
#  'accursed',
#  'accusation',
#  'accusations',
#  'accuse',
#  'accuses',
#  'accusing',
#  'accusingly',
#  'acerbate',
#  'acerbic',
#  'acerbically',
#  'ache',
#  'ached',
#  'aches',
#  'aching',
#  'acrid',
#  'acridly',
#  'acridness',
#  'acrimonious',
#  'acrimoniously',
#  'acrimony',
#  'adamant',
#  'adamantly',
#  'addict',
#  'addicted',
#  'addicting',
#  'addicts',
#  'admonish',
#  'admonisher',
#  'admonishingly',
#  'admonishment',
#  'admonition',
#  'adulterate',
#  'adulterated',
#  'adulteration',
#  'adversarial',
# ...

# %%
# Sentiment Score Tracker
# if there is more positive words than negative, it is positive review
# else negative review

# %%
from textblob import TextBlob

df['Scores'] = df['Cleaned_Text'].apply(lambda b: round(TextBlob(b).polarity))

# %%
df
# Out:
#                               Restaurant Name  \
# 0                     ZuZu at Hotel Valley Ho
# 1                                Cafe Monarch
# 2                              Mowry & Cotton
# 3                      Franco's Italian Caffe
# 4                          The Capital Grille
# 5                 Butterfield's Pancake House
# 6                            JOJO Coffeehouse
# 7                                      Craft
# 8                                       Virtu
# 9                        Rehab Burger Therapy
# 10                    Butters Pancakes & Cafe
# 11                 Grassroots Kitchen and Tap
# 12                                     Steak
# 13   Elements at Sanctuary Camelback Mountain
# 14                     Roka Akor - Scottsdale
# 15                                      deseo
# 16                    Eddie V's Prime Seafood
# 17                      Dominick's Steakhouse
# 18                          True Food Kitchen
# ...
